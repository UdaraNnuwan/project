# %%
import os, gc, joblib
import numpy as np
import tensorflow as tf

X_PATH = "../data/processed/X_all.npy"
C_PATH = "../data/processed/C_all.npy"

X_all = np.load(X_PATH, allow_pickle=False)
C_all = np.load(C_PATH, allow_pickle=False)

print("Loaded ✅")
print("X_all:", X_all.shape, X_all.dtype)
print("C_all:", C_all.shape, C_all.dtype)

assert X_all.ndim == 3, "X_all must be (N,T,F)"
assert C_all.ndim == 2, "C_all must be (N,context_dim)"
assert len(X_all) == len(C_all), "X_all and C_all must have same N"

# NaN cleanup (safe)
nan_ratio = np.isnan(X_all).mean()
if nan_ratio > 0:
    print(f"⚠ NaNs in X_all: {nan_ratio*100:.3f}% -> filling 0")
    X_all = np.nan_to_num(X_all, nan=0.0)

os.makedirs("../saved_model", exist_ok=True)
# Out:
# 2026-03-06 22:54:10.055911: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loaded ✅
# X_all: (772049, 24, 8) float32
# C_all: (772049, 5) float32

# %%
from sklearn.model_selection import train_test_split

X_tr, X_val, C_tr, C_val = train_test_split(
    X_all, C_all,
    test_size=0.2,
    random_state=42,
    shuffle=True
)

print("Split ✅")
print("X_tr :", X_tr.shape, "C_tr :", C_tr.shape)
print("X_val:", X_val.shape, "C_val:", C_val.shape)
# Out:
# Split ✅
# X_tr : (617639, 24, 8) C_tr : (617639, 5)
# X_val: (154410, 24, 8) C_val: (154410, 5)

# %%
from sklearn.preprocessing import RobustScaler, StandardScaler

# ----- Scale X -----
scaler = RobustScaler(quantile_range=(25, 75))

N_tr, T, F = X_tr.shape
scaler.fit(X_tr.reshape(N_tr*T, F))

def apply_scaler(sc, X):
    N, T, F = X.shape
    X2 = sc.transform(X.reshape(N*T, F))
    return X2.reshape(N, T, F).astype(np.float32)

X_trs  = apply_scaler(scaler, X_tr)
X_vals = apply_scaler(scaler, X_val)

# ----- Scale Context (C) -----
ctx_scaler = StandardScaler()
C_tr  = ctx_scaler.fit_transform(C_tr).astype(np.float32)
C_val = ctx_scaler.transform(C_val).astype(np.float32)

# Save scalers
joblib.dump(scaler, "../saved_model/scaler.joblib")
joblib.dump(ctx_scaler, "../saved_model/ctx_scaler.joblib")

# ----- Dynamic TOPK -----
WINDOW_SIZE = X_trs.shape[1]
N_FEATURES  = X_trs.shape[2]
TOPK = max(10, int(0.10 * (WINDOW_SIZE * N_FEATURES)))

print("Scaled ✅")
print("X_trs :", X_trs.shape, X_trs.dtype)
print("X_vals:", X_vals.shape, X_vals.dtype)
print("C_tr  :", C_tr.shape,  C_tr.dtype)
print("C_val :", C_val.shape, C_val.dtype)
print("TOPK  :", TOPK)
# Out:
# Scaled ✅
# X_trs : (617639, 24, 8) float32
# X_vals: (154410, 24, 8) float32
# C_tr  : (617639, 5) float32
# C_val : (154410, 5) float32
# TOPK  : 19

# %%
import os, sys
sys.path.append(os.path.abspath(".."))

from src.model import build_film_ae  # must exist in src/model.py

CTX_DIM = C_tr.shape[1]
model = build_film_ae(WINDOW_SIZE, N_FEATURES, CTX_DIM, units=64, latent=64)

model.summary()
# Out:
# 2026-03-06 22:54:16.342847: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Model: "film_ae"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ x (InputLayer)      │ (None, 24, 8)     │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc1_conv (Conv1D)  │ (None, 24, 64)    │      1,600 │ x[0][0]           │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ context             │ (None, 5)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc1_film (FiLM)    │ (None, 24, 64)    │        768 │ enc1_conv[0][0],  │
# │                     │                   │            │ context[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc1_relu           │ (None, 24, 64)    │          0 │ enc1_film[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc2_conv (Conv1D)  │ (None, 24, 64)    │     12,352 │ enc1_relu[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc2_film (FiLM)    │ (None, 24, 64)    │        768 │ enc2_conv[0][0],  │
# │                     │                   │            │ context[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc2_relu           │ (None, 24, 64)    │          0 │ enc2_film[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gap                 │ (None, 64)        │          0 │ enc2_relu[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z (Dense)           │ (None, 64)        │      4,160 │ gap[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_dense (Dense)   │ (None, 1536)      │     99,840 │ z[0][0]           │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_reshape         │ (None, 24, 64)    │          0 │ dec_dense[0][0]   │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec1_conv (Conv1D)  │ (None, 24, 64)    │     12,352 │ dec_reshape[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec1_film (FiLM)    │ (None, 24, 64)    │        768 │ dec1_conv[0][0],  │
# │                     │                   │            │ context[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec1_relu           │ (None, 24, 64)    │          0 │ dec1_film[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_conv (Conv1D)   │ (None, 24, 64)    │     12,352 │ dec1_relu[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out (Conv1D)        │ (None, 24, 8)     │      1,544 │ dec_conv[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 146,504 (572.28 KB)
#  Trainable params: 146,504 (572.28 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cb = [
    tf.keras.callbacks.EarlyStopping(patience=12, restore_best_weights=True),
    tf.keras.callbacks.ReduceLROnPlateau(patience=4, factor=0.5, min_lr=1e-6),
]
history = model.fit(
    [X_trs, C_tr], X_trs,
    validation_data=([X_vals, C_val], X_vals),
    epochs=80,
    batch_size=128,
    callbacks=cb,
    verbose=1
)
# Out:
# 2026-03-06 22:54:16.586514: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:84] Allocation of 474346752 exceeds 10% of free system memory.
# Epoch 1/80
# 2026-03-06 22:54:16.828946: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:84] Allocation of 474346752 exceeds 10% of free system memory.
# 4826/4826 ━━━━━━━━━━━━━━━━━━━━ 37s 7ms/step - loss: 15915.9658 - val_loss: 1885.1997 - learning_rate: 0.0010
# Epoch 2/80
# 4826/4826 ━━━━━━━━━━━━━━━━━━━━ 37s 8ms/step - loss: 76.4976 - val_loss: 4.4338 - learning_rate: 0.0010
# Epoch 3/80
# 4826/4826 ━━━━━━━━━━━━━━━━━━━━ 37s 8ms/step - loss: 2.1657 - val_loss: 2.1189 - learning_rate: 0.0010
# Epoch 4/80
# 4826/4826 ━━━━━━━━━━━━━━━━━━━━ 37s 8ms/step - loss: 2.2084 - val_loss: 2.1750 - learning_rate: 0.0010
# Epoch 5/80
# 4826/4826 ━━━━━━━━━━━━━━━━━━━━ 37s 8ms/step - loss: 2.2827 - val_loss: 256.5173 - learning_rate: 0.0010
# Epoch 6/80
# 4826/4826 ━━━━━━━━━━━━━━━━━━━━ 37s 8ms/step - loss: 52.9781 - val_loss: 2.7312 - learning_rate: 0.0010
# Epoch 7/80
# 4826/4826 ━━━━━━━━━━━━━━━━━━━━ 37s 8ms/step - loss: 1.9990 - val_loss: 2.1369 - learning_rate: 5.0000e-04
# Epoch 8/80
# 4826/4826 ━━━━━━━━━━━━━━━━━━━━ 37s 8ms/step - loss: 7.1095 - val_loss: 1.9771 - learning_rate: 5.0000e-04
# Epoch 9/80
# 4826/4826 ━━━━━━━━━━━━━━━━━━━━ 37s 8ms/step - loss: 2.3111 - val_loss: 2.0911 - learning_rate: 5.0000e-04
# Epoch 10/80
# 4826/4826 ━━━━━━━━━━━━━━━━━━━━ 39s 8ms/step - loss: 1.9530 - val_loss: 9.3788 - learning_rate: 5.0000e-04
# Epoch 11/80
# 4826/4826 ━━━━━━━━━━━━━━━━━━━━ 40s 8ms/step - loss: 7.8797 - val_loss: 2.0193 - learning_rate: 5.0000e-04
# Epoch 12/80
# 4826/4826 ━━━━━━━━━━━━━━━━━━━━ 40s 8ms/step - loss: 1.7082 - val_loss: 1.9307 - learning_rate: 2.5000e-04
# Epoch 13/80
# 4826/4826 ━━━━━━━━━━━━━━━━━━━━ 40s 8ms/step - loss: 1.6763 - val_loss: 1.8992 - learning_rate: 2.5000e-04
# Epoch 14/80
# 4826/4826 ━━━━━━━━━━━━━━━━━━━━ 40s 8ms/step - loss: 1.9327 - val_loss: 1.8733 - learning_rate: 2.5000e-04
# Epoch 15/80
# 4826/4826 ━━━━━━━━━━━━━━━━━━━━ 69056s 14s/step - loss: 1.6308 - val_loss: 1.8610 - learning_rate: 2.5000e-04
# Epoch 16/80
# 4826/4826 ━━━━━━━━━━━━━━━━━━━━ 46s 10ms/step - loss: 1.6055 - val_loss: 1.8489 - learning_rate: 2.5000e-04
# Epoch 17/80
# 4826/4826 ━━━━━━━━━━━━━━━━━━━━ 49s 10ms/step - loss: 5.7875 - val_loss: 1.8311 - learning_rate: 2.5000e-04
# Epoch 18/80
# 4826/4826 ━━━━━━━━━━━━━━━━━━━━ 49s 10ms/step - loss: 1.5524 - val_loss: 1.8326 - learning_rate: 2.5000e-04
# Epoch 19/80
# 4826/4826 ━━━━━━━━━━━━━━━━━━━━ 49s 10ms/step - loss: 1.5192 - val_loss: 1.8237 - learning_rate: 2.5000e-04
# Epoch 20/80
# 4826/4826 ━━━━━━━━━━━━━━━━━━━━ 47s 10ms/step - loss: 1.5063 - val_loss: 1.7634 - learning_rate: 2.5000e-04
# Epoch 21/80
# 4826/4826 ━━━━━━━━━━━━━━━━━━━━ 51s 11ms/step - loss: 1.5537 - val_loss: 1.7683 - learning_rate: 2.5000e-04
# Epoch 22/80
# 4826/4826 ━━━━━━━━━━━━━━━━━━━━ 49s 10ms/step - loss: 1.4772 - val_loss: 1.7403 - learning_rate: 2.5000e-04
# Epoch 23/80
# 4826/4826 ━━━━━━━━━━━━━━━━━━━━ 49s 10ms/step - loss: 1.4526 - val_loss: 1.7254 - learning_rate: 2.5000e-04
# Epoch 24/80
# 4826/4826 ━━━━━━━━━━━━━━━━━━━━ 50s 10ms/step - loss: 1.5134 - val_loss: 1.6957 - learning_rate: 2.5000e-04
# Epoch 25/80
# 4826/4826 ━━━━━━━━━━━━━━━━━━━━ 56s 12ms/step - loss: 1.4246 - val_loss: 1.7550 - learning_rate: 2.5000e-04
# Epoch 26/80
# 4826/4826 ━━━━━━━━━━━━━━━━━━━━ 51s 11ms/step - loss: 2.7647 - val_loss: 1.7190 - learning_rate: 2.5000e-04
# Epoch 27/80
# 4826/4826 ━━━━━━━━━━━━━━━━━━━━ 52s 11ms/step - loss: 1.3921 - val_loss: 1.7153 - learning_rate: 2.5000e-04
# Epoch 28/80
# 4826/4826 ━━━━━━━━━━━━━━━━━━━━ 56s 12ms/step - loss: 1.3172 - val_loss: 1.7058 - learning_rate: 1.2500e-04
# Epoch 29/80
# 4826/4826 ━━━━━━━━━━━━━━━━━━━━ 55s 11ms/step - loss: 1.3023 - val_loss: 1.6752 - learning_rate: 1.2500e-04
# Epoch 30/80
# 4826/4826 ━━━━━━━━━━━━━━━━━━━━ 56s 12ms/step - loss: 1.2716 - val_loss: 1.7448 - learning_rate: 1.2500e-04
# Epoch 31/80
# 4826/4826 ━━━━━━━━━━━━━━━━━━━━ 54s 11ms/step - loss: 1.2578 - val_loss: 1.6615 - learning_rate: 1.2500e-04
# Epoch 32/80
# 4826/4826 ━━━━━━━━━━━━━━━━━━━━ 55s 11ms/step - loss: 1.6444 - val_loss: 1.6932 - learning_rate: 1.2500e-04
# Epoch 33/80
# 4826/4826 ━━━━━━━━━━━━━━━━━━━━ 54s 11ms/step - loss: 1.2084 - val_loss: 1.6848 - learning_rate: 1.2500e-04
# Epoch 34/80
# 4826/4826 ━━━━━━━━━━━━━━━━━━━━ 55s 11ms/step - loss: 1.1945 - val_loss: 1.6798 - learning_rate: 1.2500e-04
# Epoch 35/80
# 4826/4826 ━━━━━━━━━━━━━━━━━━━━ 55s 11ms/step - loss: 1.1363 - val_loss: 1.7027 - learning_rate: 6.2500e-05
# Epoch 36/80
# 4826/4826 ━━━━━━━━━━━━━━━━━━━━ 51s 11ms/step - loss: 1.1091 - val_loss: 1.6800 - learning_rate: 6.2500e-05
# Epoch 37/80
# 4826/4826 ━━━━━━━━━━━━━━━━━━━━ 47s 10ms/step - loss: 1.0924 - val_loss: 1.7266 - learning_rate: 6.2500e-05

# %%
# Reconstruction on train to compute threshold
X_tr_pred = model.predict([X_trs, C_tr], verbose=0)

def topk_score(x_true, x_pred, k):
    err = (x_true - x_pred) ** 2
    flat = err.reshape(len(err), -1)
    k = min(k, flat.shape[1])
    part = np.partition(flat, -k, axis=1)[:, -k:]
    return np.mean(part, axis=1)

train_scores = topk_score(X_trs, X_tr_pred, TOPK)

# simple robust threshold (percentile)
THRESH = float(np.percentile(train_scores, 95))

detector_meta = {"topk": int(TOPK), "threshold": THRESH}
joblib.dump(detector_meta, "../saved_model/detector_meta.joblib")

print("Detector meta saved ✅", detector_meta)
# Out:
# 2026-03-07 18:33:04.004680: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:84] Allocation of 474346752 exceeds 10% of free system memory.
# 2026-03-07 18:33:39.105257: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:84] Allocation of 474346752 exceeds 10% of free system memory.
# Detector meta saved ✅ {'topk': 19, 'threshold': 13.412670135498047}

# %%
model.save("../saved_model/ae_model.keras")
print("Model saved ✅ -> ../saved_model/ae_model.keras")
# Out:
# Model saved ✅ -> ../saved_model/ae_model.keras
